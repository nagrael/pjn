# %%
import os
import numpy as np
from scipy import sparse
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import classification_report, accuracy_score, precision_recall_fscore_support
from sklearn.svm import SVC, LinearSVC
import pickle

names = ["A?C.*",
       "A?U.*",
       "A?K.*",
       "G.*",
       "A?P.*",
       "R.*",
       "W.*",
       "Am.*", ]

# %%
with open("result_list", "rb") as f:
    classes = pickle.load(f)
for i, cla in enumerate(classes):
    print("Class {} has {} samples.".format(names[i], len(cla)))
# Out:
# Class A?C.* has 24121 samples.
# Class A?U.* has 8379 samples.
# Class A?K.* has 10574 samples.
# Class G.* has 3505 samples.
# Class A?P.* has 2661 samples.
# Class R.* has 1060 samples.
# Class W.* has 1062 samples.
# Class Am.* has 599 samples.

# %%
def SVM_test(path):
    with open(os.path.join(path, "train_perm"), "r") as f:
        train_ans = literal_eval(f.read())
    with open(os.path.join(path, "test_perm"), "r") as f:
        test_ans = literal_eval(f.read())
    X_test = TfidfTransformer(use_idf=True).fit_transform(sparse.load_npz(os.path.join(path, "sparse_test.npz")))
    X_train = TfidfTransformer(use_idf=True).fit_transform(sparse.load_npz(os.path.join(path, "sparse_train.npz")))
    print(X_test.shape)
    print(X_train.shape)
    for i, name in enumerate(names):
        print(name)
        Y_train = np.array([1 if x == i else 0 for x in train_ans])
        Y_test = np.array([1 if x == i else 0 for x in test_ans])
        cla = SVC(kernel="linear", C=100)
        cla.fit(X_train, Y_train)
        Y_pre =cla.predict(X_test)
        print("accuracy_score") 
        print(accuracy_score(Y_test, Y_pre))
        print("classification_report")
        print(classification_report(Y_test, Y_pre))
        print("micro_report")
        print(precision_recall_fscore_support(Y_test, Y_pre, average='micro'))
        print("macro_report")
        print(precision_recall_fscore_support(Y_test, Y_pre, average='macro'))

# %%
SVM_test("trans")
# Out:
# (11647, 192519)
# (34927, 192519)
# A?C.*
# accuracy_score
# 0.951489653988
# classification_report
#              precision    recall  f1-score   support
#
#           0       0.95      0.96      0.96      6335
#           1       0.95      0.95      0.95      5312
#
# avg / total       0.95      0.95      0.95     11647
#
# micro_report
# (0.95148965398815144, 0.95148965398815144, 0.95148965398815144, None)
# macro_report
# (0.95115596069587993, 0.95105929836156, 0.95110727808649786, None)
# A?U.*
# accuracy_score
# 0.999141409805
# classification_report
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      9604
#           1       1.00      1.00      1.00      2043
#
# avg / total       1.00      1.00      1.00     11647
#
# micro_report
# (0.99914140980510002, 0.99914140980510002, 0.99914140980510002, None)
# macro_report
# (0.99813393075232049, 0.99890135412251746, 0.99851714368797451, None)
# A?K.*
# accuracy_score
# 0.99665149824
# classification_report
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      9245
#           1       0.99      0.99      0.99      2402
#
# avg / total       1.00      1.00      1.00     11647
#
# micro_report
# (0.99665149823989008, 0.99665149823989008, 0.99665149823989008, None)
# macro_report
# (0.99436024664310452, 0.99542552650148675, 0.99489176507429633, None)
# G.*
# accuracy_score
# 0.969520048081
# classification_report
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98     10902
#           1       0.77      0.74      0.76       745
#
# avg / total       0.97      0.97      0.97     11647
#
# micro_report
# (0.96952004808105097, 0.96952004808105097, 0.96952004808105097, None)
# macro_report
# (0.87739082226807152, 0.8636652470638353, 0.87037797620811042, None)
# A?P.*
# accuracy_score
# 0.996393921181
# classification_report
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     11086
#           1       0.98      0.95      0.96       561
#
# avg / total       1.00      1.00      1.00     11647
#
# micro_report
# (0.99639392118142012, 0.99639392118142012, 0.99639392118142012, None)
# macro_report
# (0.98676732351721075, 0.97356697258799541, 0.98006620068322947, None)
# R.*
# accuracy_score
# 0.99836867863
# classification_report
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     11417
#           1       0.97      0.95      0.96       230
#
# avg / total       1.00      1.00      1.00     11647
#
# micro_report
# (0.99836867862969003, 0.99836867862969003, 0.99836867862969003, None)
# macro_report
# (0.9839191423957665, 0.97360648308586351, 0.97870492395646735, None)
# W.*
# accuracy_score
# 0.997681806474
# classification_report
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     11401
#           1       0.97      0.92      0.94       246
#
# avg / total       1.00      1.00      1.00     11647
#
# micro_report
# (0.99768180647377003, 0.99768180647377003, 0.99768180647377003, None)
# macro_report
# (0.98410242372329437, 0.95904260288107657, 0.97122456794851209, None)
# Am.*
# accuracy_score
# 0.999055550786
# classification_report
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     11539
#           1       0.95      0.94      0.95       108
#
# avg / total       1.00      1.00      1.00     11647
#
# micro_report
# (0.99905555078561004, 0.99905555078561004, 0.99905555078561004, None)
# macro_report
# (0.97637554868073662, 0.97200556566619478, 0.97418029276589913, None)

# %%
SVM_test("norm")
# Out:
# (11647, 302030)
# (34927, 302030)
# A?C.*
# accuracy_score
# 0.960934146132
# classification_report
#              precision    recall  f1-score   support
#
#           0       0.97      0.96      0.96      6335
#           1       0.95      0.96      0.96      5312
#
# avg / total       0.96      0.96      0.96     11647
#
# micro_report
# (0.96093414613205119, 0.96093414613205119, 0.96093414613205119, None)
# macro_report
# (0.96029135334163818, 0.96109401596124044, 0.96066580188189965, None)
# A?U.*
# accuracy_score
# 0.999313127844
# classification_report
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      9604
#           1       1.00      1.00      1.00      2043
#
# avg / total       1.00      1.00      1.00     11647
#
# micro_report
# (0.99931312784408, 0.99931312784408, 0.99931312784408, None)
# macro_report
# (0.99958385351643786, 0.99804209495839458, 0.99881096715627282, None)
# A?K.*
# accuracy_score
# 0.997166652357
# classification_report
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      9245
#           1       0.99      0.99      0.99      2402
#
# avg / total       1.00      1.00      1.00     11647
#
# micro_report
# (0.99716665235683011, 0.99716665235683011, 0.99716665235683011, None)
# macro_report
# (0.99590051398290236, 0.99544187307404286, 0.99567098650442709, None)
# G.*
# accuracy_score
# 0.977075641796
# classification_report
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99     10902
#           1       0.85      0.77      0.81       745
#
# avg / total       0.98      0.98      0.98     11647
#
# micro_report
# (0.97707564179617068, 0.97707564179617068, 0.97707564179617068, None)
# macro_report
# (0.91911859884504543, 0.88270787085431035, 0.89994866083342795, None)
# A?P.*
# accuracy_score
# 0.994590881772
# classification_report
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     11086
#           1       0.97      0.91      0.94       561
#
# avg / total       0.99      0.99      0.99     11647
#
# micro_report
# (0.99459088177213018, 0.99459088177213018, 0.99459088177213018, None)
# macro_report
# (0.98448897591409801, 0.95569655871467374, 0.96960268750055145, None)
# R.*
# accuracy_score
# 0.998626255688
# classification_report
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     11417
#           1       0.98      0.95      0.96       230
#
# avg / total       1.00      1.00      1.00     11647
#
# micro_report
# (0.99862625568815999, 0.99862625568815999, 0.99862625568815999, None)
# macro_report
# (0.98835780099048287, 0.97586798481288395, 0.98202859192852787, None)
# W.*
# accuracy_score
# 0.998196960591
# classification_report
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     11401
#           1       0.97      0.94      0.96       246
#
# avg / total       1.00      1.00      1.00     11647
#
# micro_report
# (0.99819696059071006, 0.99819696059071006, 0.99819696059071006, None)
# macro_report
# (0.986684454009918, 0.96924906030921543, 0.97780056532603454, None)
# Am.*
# accuracy_score
# 0.999227268825
# classification_report
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00     11539
#           1       0.98      0.94      0.96       108
#
# avg / total       1.00      1.00      1.00     11647
#
# micro_report
# (0.99922726882459001, 0.99922726882459001, 0.99922726882459001, None)
# macro_report
# (0.9899880743327345, 0.96750592997018159, 0.97847803711847203, None)

# %%
def lin_SVM_test(path):
    with open(os.path.join(path, "train_perm"), "r") as f:
        Y_train = literal_eval(f.read())
    with open(os.path.join(path, "test_perm"), "r") as f:
        Y_test = literal_eval(f.read())
    X_test = TfidfTransformer(use_idf=True).fit_transform(sparse.load_npz(os.path.join(path, "sparse_test.npz")))
    X_train = TfidfTransformer(use_idf=True).fit_transform(sparse.load_npz(os.path.join(path, "sparse_train.npz")))
    print(X_test.shape)
    print(X_train.shape)
    for i, name in enumerate(names):
        print(name)
        cla = LinearSVC(C=100)
        cla.fit(X_train, Y_train)
        Y_pre = cla.predict(X_test)
        print("accuracy_score") 
        print(accuracy_score(Y_test, Y_pre))
        print("classification_report")
        print(classification_report(Y_test, Y_pre))
        print("micro_report")
        print(precision_recall_fscore_support(Y_test, Y_pre, average='micro'))
        print("macro_report")
        print(precision_recall_fscore_support(Y_test, Y_pre, average='macro'))

# %%
lin_SVM_test("norm")
# Out:
# (11647, 302030)
# (34927, 302030)
# A?C.*
# accuracy_score
# 0.967888726711
# classification_report
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97      5312
#           1       1.00      1.00      1.00      2043
#           2       0.99      0.99      0.99      2402
#           3       0.86      0.79      0.82       745
#           4       0.97      0.93      0.95       561
#           5       0.96      0.95      0.96       230
#           6       0.98      0.94      0.96       246
#           7       0.98      0.95      0.97       108
#
# avg / total       0.97      0.97      0.97     11647
#
# micro_report
# (0.967888726710741, 0.967888726710741, 0.967888726710741, None)
# macro_report
# (0.96207765027784808, 0.94157367873483611, 0.95155207296648325, None)
# A?U.*
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-49e4b49d816b> in <module>()
# ----> 1 lin_SVM_test("norm")
#
# <ipython-input-5-70e511a2c80c> in lin_SVM_test(path)
#      11         print(name)
#      12         cla = LinearSVC(C=100)
# ---> 13         cla.fit(X_train, Y_train)
#      14         Y_pre =cla.predict(X_test)
#      15         print("accuracy_score")
#
# /usr/lib64/python3.6/site-packages/sklearn/svm/classes.py in fit(self, X, y, sample_weight)
#     233             self.class_weight, self.penalty, self.dual, self.verbose,
#     234             self.max_iter, self.tol, self.random_state, self.multi_class,
# --> 235             self.loss, sample_weight=sample_weight)
#     236
#     237         if self.multi_class == "crammer_singer" and len(self.classes_) == 2:
#
# /usr/lib64/python3.6/site-packages/sklearn/svm/base.py in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     888         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     889         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
# --> 890         epsilon, sample_weight)
#     891     # Regarding rnd.randint(..) in the above signature:
#     892     # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# KeyboardInterrupt:

# %%
lin_SVM_test("trans")
# Out:
# (11647, 192519)
# (34927, 192519)
# A?C.*
# accuracy_score
# 0.959474542801
# classification_report
#              precision    recall  f1-score   support
#
#           0       0.96      0.96      0.96      5312
#           1       1.00      1.00      1.00      2043
#           2       0.99      1.00      0.99      2402
#           3       0.77      0.74      0.76       745
#           4       0.97      0.95      0.96       561
#           5       0.95      0.92      0.94       230
#           6       0.97      0.93      0.95       246
#           7       0.95      0.95      0.95       108
#
# avg / total       0.96      0.96      0.96     11647
#
# micro_report
# (0.9594745428007212, 0.9594745428007212, 0.9594745428007212, None)
# macro_report
# (0.94403062311090036, 0.93189794851959262, 0.93784550736366068, None)
# A?U.*
# accuracy_score
# 0.959474542801
# classification_report
#              precision    recall  f1-score   support
#
#           0       0.96      0.96      0.96      5312
#           1       1.00      1.00      1.00      2043
#           2       0.99      1.00      0.99      2402
#           3       0.77      0.74      0.76       745
#           4       0.97      0.95      0.96       561
#           5       0.95      0.92      0.94       230
#           6       0.97      0.93      0.95       246
#           7       0.95      0.95      0.95       108
#
# avg / total       0.96      0.96      0.96     11647
#
# micro_report
# (0.9594745428007212, 0.9594745428007212, 0.9594745428007212, None)
# macro_report
# (0.94403062311090036, 0.93189794851959262, 0.93784550736366068, None)
# A?K.*
# accuracy_score
# 0.959474542801
# classification_report
#              precision    recall  f1-score   support
#
#           0       0.96      0.96      0.96      5312
#           1       1.00      1.00      1.00      2043
#           2       0.99      1.00      0.99      2402
#           3       0.77      0.74      0.76       745
#           4       0.97      0.95      0.96       561
#           5       0.95      0.92      0.94       230
#           6       0.97      0.93      0.95       246
#           7       0.95      0.95      0.95       108
#
# avg / total       0.96      0.96      0.96     11647
#
# micro_report
# (0.9594745428007212, 0.9594745428007212, 0.9594745428007212, None)
# macro_report
# (0.94403062311090036, 0.93189794851959262, 0.93784550736366068, None)
# G.*
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-640ac3ee00f4> in <module>()
# ----> 1 lin_SVM_test("trans")
#
# <ipython-input-5-70e511a2c80c> in lin_SVM_test(path)
#      11         print(name)
#      12         cla = LinearSVC(C=100)
# ---> 13         cla.fit(X_train, Y_train)
#      14         Y_pre =cla.predict(X_test)
#      15         print("accuracy_score")
#
# /usr/lib64/python3.6/site-packages/sklearn/svm/classes.py in fit(self, X, y, sample_weight)
#     233             self.class_weight, self.penalty, self.dual, self.verbose,
#     234             self.max_iter, self.tol, self.random_state, self.multi_class,
# --> 235             self.loss, sample_weight=sample_weight)
#     236
#     237         if self.multi_class == "crammer_singer" and len(self.classes_) == 2:
#
# /usr/lib64/python3.6/site-packages/sklearn/svm/base.py in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     888         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     889         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
# --> 890         epsilon, sample_weight)
#     891     # Regarding rnd.randint(..) in the above signature:
#     892     # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# KeyboardInterrupt:
